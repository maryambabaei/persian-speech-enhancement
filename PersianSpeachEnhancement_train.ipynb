# %%
# Install SpeachBrain Library and import it
# %%capture
# !pip install speechbrain

import os
import speechbrain as sb
import torch
import numpy as np
from IPython.display import Audio, display

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Config and hyper paramters

# %%
# path to the cvfa.tar.gz
zip_path = '/content/drive/MyDrive/speechbrain/templates/enhancement/data/cvfa.tar.gz'

# path to save results after training
save_path = '/content/drive/MyDrive/FA_spech_enhance_exp_5020/'

# device to train on
device = 'cpu'
# choose wich data subset you want to see results from ['train', 'valid', 'test']
data_subset = ['train']
#choose number of samples you want see results
sample_num = 5

# %%
# %%writefile train.yaml
#
# # #################################
# # Basic training parameters for enhancement.
# # #################################
#
# # Seed needs to be set at top of yaml, before objects with parameters are made
# seed: 5020
# __set_seed: !!python/object/apply:torch.manual_seed [!ref <seed>]
#
# # Set up folders for reading from and writing to
# data_folder: ./data
# output_folder: !ref ./results/<seed>
# save_folder: !ref <output_folder>/save
# train_log: !ref <output_folder>/train_log.txt
#
# # Path where data manifest files will be stored
# # The data manifest files are created by the data preparation script.
# train_annotation: train.json
# valid_annotation: valid.json
# test_annotation: test.json
#
#
# # FFT parameters
# sample_rate: 48000
# win_length: 32
# hop_length: 16
# n_fft: 512
# window_fn: !name:torch.hamming_window
#
# # Training Parameters
# number_of_epochs: 40
# batch_size: 8
# learning_rate: 0.0001
# dataloader_options:
#     batch_size: !ref <batch_size>
#
# # Added noise and reverb come from OpenRIR dataset, automatically
# # downloaded and prepared with this Environmental Corruption class.
# # The babble is generated from other utterances in each batch.
# env_corruption: !new:speechbrain.lobes.augment.EnvCorrupt
#     openrir_folder: !ref <data_folder>
#     #reverb_csv:
#     #noise_csv:
#     #noise_prob: 0
#     openrir_max_noise_len: 10
#     noise_snr_low: 0
#     noise_snr_high: 15
#     #babble_prob: 1
#     babble_speaker_count: !ref <batch_size> - 1
#     babble_snr_low: 0
#     babble_snr_high: 15
#
#
#
# # The train logger writes training statistics to a file, as well as stdout.
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
#
#
# # The mask operates on log-spectral features, computed using these
# # STFT parameters, as well as computing magnitude and log1p.
# compute_STFT: !new:speechbrain.processing.features.STFT
#     sample_rate: !ref <sample_rate>
#     win_length: !ref <win_length>
#     hop_length: !ref <hop_length>
#     n_fft: !ref <n_fft>
#     window_fn: !ref <window_fn>
# compute_ISTFT: !new:speechbrain.processing.features.ISTFT
#     sample_rate: !ref <sample_rate>
#     win_length: !ref <win_length>
#     hop_length: !ref <hop_length>
#     window_fn: !ref <window_fn>
#
# # Resynthesize combines noisy phase with enhanced magnitudes.
# resynth: !name:speechbrain.processing.signal_processing.resynthesize
#     stft: !ref <compute_STFT>
#     istft: !ref <compute_ISTFT>
#
# # To design a custom model, either just edit the simple CustomModel
# # class that's listed here, or replace this `!new` call with a line
# # pointing to a different file you've defined.
# model: !new:custom_model.CustomModel
#     input_size: !ref <n_fft> // 2 + 1
#
# # The first object passed to the Brain class is this "Epoch Counter"
# # which is saved by the Checkpointer so that training can be resumed
# # if it gets interrupted at any point.
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <number_of_epochs>
#
# # Objects in "modules" dict will have their parameters moved to the correct
# # device, as well as having train()/eval() called on them by the Brain class.
# modules:
#     model: !ref <model>
#
# # This optimizer will be constructed by the Brain class after all parameters
# # are moved to the correct device. Then it will be added to the checkpointer.
# opt_class: !name:torch.optim.Adam
#     lr: !ref <learning_rate>
#
# # This object is used for saving the state of training both so that it
# # can be resumed if it gets interrupted, and also so that the best checkpoint
# # can be later loaded for evaluation or inference.
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         model: !ref <model>
#         counter: !ref <epoch_counter>
# Out:
# Writing train.yaml

# %%
# %%writefile custom_model.py
# define custome model that predicts the mask
import torch

class CustomModel(torch.nn.Module):
    """Basic RNN model with projection layers between RNN layers.

    Arguments
    ---------
    input_size : int
        Size of the expected input in the 3rd dimension.
    rnn_size : int
        Number of neurons to use in rnn (for each direction -> and <-).
    projection : int
        Number of neurons in projection layer.
    layers : int
        Number of RNN layers to use.
    """

    def __init__(self, input_size, rnn_size=256, projection=128, layers=2):
        super().__init__()
        self.layers = torch.nn.ModuleList()

        # Alternate RNN and projection layers.
        for i in range(layers):
            self.layers.append(
                torch.nn.LSTM(
                    input_size=input_size if i == 0 else projection,
                    hidden_size=rnn_size,
                    bidirectional=True,
                )
            )

            # Projection layer reduces size, except last layer, which
            # goes back to input size to create the mask
            linear_size = input_size if i == layers - 1 else projection
            self.layers.append(
                torch.nn.Linear(
                    in_features=rnn_size * 2, out_features=linear_size,
                )
            )

        # Use ReLU to make sure outputs aren't negative (unhelpful for masking)
        self.layers.append(torch.nn.ReLU())

    def forward(self, x):
        """Shift to time-first, pass layers, then back to batch-first."""
        x = x.transpose(0, 1)
        for layer in self.layers:
            x = layer(x)
            if isinstance(x, tuple):
                x = x[0]
        x = x.transpose(0, 1)
        return x
# Out:
# Writing custom_model.py

# %%
from hyperpyyaml import load_hyperpyyaml
with open("train.yaml") as fin:
  hparams = load_hyperpyyaml(fin)
# Out:
# Downloading http://www.openslr.org/resources/28/rirs_noises.zip to ./data/rirs_noises.zip
# rirs_noises.zip: 1.31GB [01:11, 18.4MB/s]
# Extracting ./data/rirs_noises.zip to ./data

# %%
# make data folder if does not exist
if not os.path.exists(hparams["data_folder"]):
    os.makedirs(hparams["data_folder"])

# %% [markdown]
# # Prepare Data

# %% [markdown]
# ## Noise Data

# %% [markdown]
# we use `speechbrain.lobes.augment.EnvCorrupt` to add noise to data. by default it uses OpenIrir Data set as noises. by setting `openrir_folder` in hyperparameters it searches the folder for Openrir dataset and downloads it if it wasn't available.
#
#
# in order to use other files as noise. we should provide `noise_csv` and `reverb_csv` in hyperparameters with csv files conrain wav files in bellow format.
#
# \begin{array}{ccc}
# \text{ID}&\text{duration}&\text{wav}&\text{wav_format}&\text{wav_opts}\\
# file\_id&file\_durarion&path/to/file& file_format
# \end{array}

# %% [markdown]
# ## Speech Data

# %% [markdown]
# ### Extract and split speech data
#
# in data folder there should be a folder containing speechdata. this folder must have three subfolders name 'train', 'valid', 'test' that contain our clean speech samples for train, validation and test.

# %%
extract_path = hparams["data_folder"] + '/cv-extracted/'
clips_path = extract_path + 'cv-corpus-7.0-2021-07-21/fa/clips'
voices_folder_path = hparams["data_folder"] + "/fa_speech"

# %%
# make folder to extract files
# !mkdir -p $extract_path
#extract files
# !tar -xvf $zip_path -C $extract_path
# !mv -v  $clips_path ./data
# !mv -v ./data/clips $voices_folder_path
# Out:
# Streaming output truncated to the last 5000 lines.
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310504.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310505.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310506.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310507.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310508.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310509.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310510.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310511.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310512.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310513.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310514.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310515.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310516.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310517.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310523.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310524.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310525.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310526.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310527.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310543.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310546.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310548.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310551.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310552.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310553.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310554.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310556.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310558.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310559.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310563.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310564.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310565.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310566.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310567.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310568.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310569.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310570.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310571.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25310572.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349300.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349301.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349307.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349308.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349309.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349315.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349317.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349318.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349321.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25349322.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356409.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356415.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356416.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356417.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356418.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356419.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356420.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356421.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356422.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356423.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356424.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356426.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356436.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25356437.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25369101.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25369102.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25369103.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25373349.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25373350.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25373353.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25373355.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25373356.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381386.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381387.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381388.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381389.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381390.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381391.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381392.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381393.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381394.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381395.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381412.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381413.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381414.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381415.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381416.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381417.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381418.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381419.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381420.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381421.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381422.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381423.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381424.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381425.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381426.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381427.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381428.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381429.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381430.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381431.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381437.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381438.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381439.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381440.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381441.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381442.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381443.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381444.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381445.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381446.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381447.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381448.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381449.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381450.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25381451.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400774.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400775.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400776.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400777.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400778.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400779.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400780.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400781.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400782.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25400783.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411469.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411470.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411471.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411472.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411473.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411474.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411475.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411476.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411477.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25411479.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428973.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428974.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428975.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428976.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428977.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428987.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428989.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428990.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428991.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428996.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428998.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25428999.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429000.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429001.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429002.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429003.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429004.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429005.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429016.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429017.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429018.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429019.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25429020.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25456406.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25456407.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25456408.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25456409.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25456410.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479087.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479088.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479089.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479090.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479091.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479097.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479098.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479099.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479100.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479101.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479108.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479110.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479112.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479114.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479115.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479177.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479178.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479179.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479181.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479183.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479193.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479194.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479195.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479196.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479197.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479299.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479300.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479301.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479302.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25479303.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528045.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528046.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528047.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528049.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528050.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528053.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528054.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528056.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528057.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528058.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528061.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528062.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528065.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528066.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528067.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528080.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528081.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528082.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528083.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528084.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528087.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528088.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528089.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528090.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528091.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528094.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528095.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528096.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528098.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528099.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528102.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528104.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528106.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528107.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528108.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528112.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528113.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528114.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528115.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528116.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528119.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528120.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528121.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528122.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528123.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528125.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528126.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528127.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528128.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528130.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528489.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528490.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528491.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528492.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528493.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528507.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528508.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528509.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528510.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528511.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528513.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528514.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528517.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528520.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528522.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528525.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528526.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528530.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528534.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528535.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528540.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528544.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528545.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528546.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528547.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528562.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528563.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528564.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528565.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528566.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528575.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528576.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528579.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528580.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528586.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528587.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528588.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528589.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528590.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528601.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528603.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528605.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528608.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528609.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528620.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528621.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528623.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528624.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528625.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528628.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528629.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528630.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528631.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528632.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528648.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528651.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528652.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528653.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528654.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528664.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528665.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528666.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528667.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528668.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528683.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528684.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528685.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528686.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25528687.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25529503.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25529504.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25529505.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25529506.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25529507.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547192.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547193.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547194.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547195.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547196.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547214.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547216.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547218.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547219.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547221.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547222.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547223.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547224.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547227.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547231.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547242.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547243.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547244.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547245.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547246.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547262.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547263.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547264.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547265.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547266.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547282.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547283.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547284.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547285.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547286.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547297.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547298.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547299.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547300.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547301.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547307.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547308.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547310.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547311.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547322.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547323.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547324.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547325.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547326.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547333.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547336.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547339.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547340.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25547341.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558521.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558522.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558523.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558524.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558525.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558534.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558535.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558536.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558537.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558538.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558540.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558541.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558542.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558543.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558544.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558550.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558551.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558552.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558553.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558554.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558558.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558559.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558560.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558561.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558562.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558571.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558572.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558573.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558574.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558575.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558587.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558588.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558589.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558590.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558591.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558599.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558600.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558601.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558602.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558603.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558606.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558607.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558608.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558609.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25558610.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570263.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570264.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570265.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570266.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570267.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570275.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570276.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570277.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570278.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570279.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570286.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570287.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570288.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570289.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25570290.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573041.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573042.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573043.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573044.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573045.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573054.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573055.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573056.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573057.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25573058.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579172.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579173.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579174.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579175.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579176.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579177.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579178.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579179.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579180.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579181.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579182.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579183.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579184.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579185.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579186.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579187.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579188.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579189.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579190.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579191.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579192.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579193.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579194.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579195.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579196.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579197.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579198.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579199.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579200.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579201.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579292.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579293.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579294.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579295.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579296.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579297.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579298.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579299.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579300.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579303.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579307.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579308.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579309.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579310.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25579311.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607861.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607864.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607865.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607867.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607868.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607873.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607874.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607875.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607876.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607877.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607891.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607892.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607893.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607894.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607895.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607908.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607909.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607911.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607912.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607913.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607916.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607917.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607918.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607920.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607921.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607976.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607977.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607978.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607979.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607980.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607996.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607997.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607998.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25607999.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608000.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608001.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608002.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608003.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608004.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608007.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608014.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608019.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608021.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608023.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608025.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608056.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608057.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608058.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608059.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25608060.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621532.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621534.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621535.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621537.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621538.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621543.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621545.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621546.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621547.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621548.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621568.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621569.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621571.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621572.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621573.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621618.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621620.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621621.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621622.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621623.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621641.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621643.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621644.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621645.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621646.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621652.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621653.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621654.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621655.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621656.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621664.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621666.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621667.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621669.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621670.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621729.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621730.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621732.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621734.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621735.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621745.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621746.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621747.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621749.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621750.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621763.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621764.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621765.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621766.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621767.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621783.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621784.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621785.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621786.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25621787.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25622207.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640047.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640049.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640050.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640051.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640052.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640054.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640055.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640056.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640057.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640059.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640061.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640063.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640065.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640066.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640067.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640069.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640070.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640071.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640072.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640073.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640081.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640082.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640083.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640085.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640086.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640087.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640088.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640089.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640090.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640091.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640094.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640095.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640097.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640099.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640100.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640102.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640103.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640105.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640106.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640109.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640111.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640112.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640113.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640114.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640117.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640118.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640119.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640120.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25640121.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658591.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658593.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658595.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658596.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658597.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658600.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658601.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658602.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658603.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658605.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658631.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658632.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658634.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658637.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658640.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658655.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658657.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658659.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658661.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658663.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658671.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658672.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658673.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658674.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658675.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658686.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658687.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658688.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658689.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658690.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658721.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658722.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658723.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658724.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658725.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658745.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658747.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658748.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658749.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658750.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658756.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658757.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658758.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658759.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25658760.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25663465.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25663466.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25663467.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25663468.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25663469.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25721449.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25721450.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25721451.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25721452.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25721453.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25739157.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753619.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753620.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753621.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753624.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753627.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753674.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753675.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753676.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753677.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25753678.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803516.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803517.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803518.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803519.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803520.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803524.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803525.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803526.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803527.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803528.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803531.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803532.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803533.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803534.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803535.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803543.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803544.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803545.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803546.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803548.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803550.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803551.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803552.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803553.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803554.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803557.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803559.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803560.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803561.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803562.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803564.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803565.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803566.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803567.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803568.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803571.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803573.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803574.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803575.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803579.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803580.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803581.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803582.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803583.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803586.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803587.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803588.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803589.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25803590.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823853.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823854.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823855.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823856.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823857.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823858.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823859.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823860.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_25823861.mp3
# ...
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232233.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232234.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232235.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232236.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232237.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232243.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232244.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232245.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232246.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232247.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232261.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232262.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232263.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232264.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232265.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232277.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232278.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232279.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232280.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232281.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232292.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232293.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232294.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232295.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232297.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232308.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232309.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232310.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232311.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232312.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232372.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232373.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232374.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232375.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232376.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232398.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232399.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232400.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232401.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232402.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232424.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232426.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232428.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232430.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232431.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232607.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232608.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232609.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232610.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27232611.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245223.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245228.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245230.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245231.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245232.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245258.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245259.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245260.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245262.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245270.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245288.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245289.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245297.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245301.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245302.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245303.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245305.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245309.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245313.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245317.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245905.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245906.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245907.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245908.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245914.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245928.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245929.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245932.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245937.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245938.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245943.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245946.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245947.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245949.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245950.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245953.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245954.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245955.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245956.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245958.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245961.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245963.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245964.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245965.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245967.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245984.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245985.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245991.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245993.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27245995.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27247222.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27247223.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27247224.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27247227.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27247235.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27266792.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27266793.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27266794.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27266795.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27266796.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278520.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278521.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278522.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278523.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278524.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278541.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278542.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278543.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278544.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27278545.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27279955.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27279961.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27279965.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27279969.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27279970.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280115.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280116.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280117.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280119.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280134.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280284.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280286.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280287.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280288.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280296.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280324.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280332.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280335.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280336.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280337.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280343.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280348.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280353.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280356.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280357.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280558.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280560.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280561.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280562.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280564.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280637.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280640.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280643.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280647.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280650.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280727.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280728.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280729.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280730.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27280731.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330458.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330459.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330460.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330461.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330463.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330483.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330484.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330485.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330486.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27330487.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369608.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369609.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369762.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369763.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369764.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369765.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27369766.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387857.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387858.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387859.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387860.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387861.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387892.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387893.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387894.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387895.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27387896.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396279.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396288.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396289.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396318.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396319.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396320.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396321.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396322.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396367.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396370.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396373.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396375.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396376.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396377.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396378.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396379.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396381.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396492.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396495.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27396497.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27400448.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27400449.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27400450.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27400451.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27400452.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413025.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413027.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413032.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413036.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413039.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413040.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413041.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413042.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413048.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413049.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413066.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413071.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413077.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413079.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413087.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413095.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413099.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413113.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413116.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413133.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413144.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27413145.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27422203.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27422204.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27422205.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27422206.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27424677.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27424678.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27424679.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27424680.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27424681.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447745.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447746.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447747.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447748.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447749.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447887.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447888.mp3
# cv-corpus-7.0-2021-07-21/fa/clips/common_voice_fa_27447919.mp3
# renamed '/content/data/cv-extracted/cv-corpus-7.0-2021-07-21/fa/clips' -> './data/clips'
# renamed './data/clips' -> '/content/data/fa_speech'

# %%
'''
Create train, test, valid folders and move respective data to each folder
'''
import os, os.path, shutil
import numpy as np

# get list of all voices
voices = [f for f in os.listdir(voices_folder_path) if os.path.isfile(os.path.join(voices_folder_path, f))]
voices = np.array(voices)


# randomize idxs in order to choose train, validation and test data randomly
shuffeled_voices_idxs = np.random.permutation(len(voices)).reshape(-1)

# ratio of test and validation to all of data
test_ratio = 0.1
validation_ratio = 0.1


# split indexs
train_idx_end = int(len(shuffeled_voices_idxs) * (1 - (test_ratio + validation_ratio)))
valid_idx_end = int(len(shuffeled_voices_idxs) * (1 - test_ratio))

train_idxs = shuffeled_voices_idxs[:train_idx_end].astype(int)
valid_idxs = shuffeled_voices_idxs[train_idx_end:valid_idx_end].astype(int)
test_idxs = shuffeled_voices_idxs[valid_idx_end:].astype(int)

# move train, validation, test voices to its folder
for subset_idxs, folder_name in [(train_idxs,'train'), (valid_idxs,'valid'), (test_idxs, 'test')]:

  for voice in voices[subset_idxs]:

    new_path = os.path.join(voices_folder_path, folder_name)
    if not os.path.exists(new_path):
        os.makedirs(new_path)

    old_voice_path = os.path.join(voices_folder_path, voice)
    new_voice_path = os.path.join(new_path, voice)
    shutil.move(old_voice_path, new_voice_path)

# %% [markdown]
# ### Creat Json files

# %%
import os
import json
import shutil
import logging
from speechbrain.utils.data_utils import get_all_files, download_file
from speechbrain.dataio.dataio import read_audio

logger = logging.getLogger(__name__)
SAMPLERATE = hparams["sample_rate"]

def prepare_fa_speach(
    voices_folder_path, save_json_train, save_json_valid, save_json_test
):
    """
    Prepares the json files for Farsi speach dataset.


    Arguments
    ---------
    voices_folder_path : str
        Path to the folder where the Persian speech voices are stored.
    save_json_train : str
        Path where the train data specification file will be saved.
    save_json_valid : str
        Path where the validation data specification file will be saved.
    save_json_test : str
        Path where the test data specification file will be saved.

    Example
    -------
    >>> voices_folder_path = '/path/to/persian_speech'
    >>> prepare_mini_librispeech(voices_folder_path, 'train.json', 'valid.json', 'test.json')
    """

    # If the dataset doesn't exist yet, download it
    train_folder = os.path.join(voices_folder_path,'train')
    valid_folder = os.path.join(voices_folder_path, 'valid')
    test_folder = os.path.join(voices_folder_path, 'test')

    # List files and create manifest from list
    logger.info(
        f"Creating {save_json_train}, {save_json_valid}, and {save_json_test}"
    )
    extension = [".mp3"]
    wav_list_train = get_all_files(train_folder, match_and=extension)
    wav_list_valid = get_all_files(valid_folder, match_and=extension)
    wav_list_test = get_all_files(test_folder, match_and=extension)

    create_json(wav_list_train, save_json_train)
    create_json(wav_list_valid, save_json_valid)
    create_json(wav_list_test, save_json_test)


def create_json(wav_list, json_file):
    """
    Creates the json file given a list of wav files.

    Arguments
    ---------
    wav_list : list of str
        The list of wav files.
    json_file : str
        The path of the output json file
    """
    # Processing all the wav files in the list
    json_dict = {}
    for wav_file in wav_list:

        # Reading the signal (to retrieve duration in seconds)
        signal = read_audio(wav_file)
        duration = signal.shape[0] / SAMPLERATE

        # Manipulate path to get relative path and uttid
        path_parts = wav_file.split(os.path.sep)
        #print(path_parts[-3:])
        uttid, _ = os.path.splitext(path_parts[-1])
        relative_path = os.path.join("{data_root}", *path_parts[-3:])

        # Create entry for this utterance
        json_dict[uttid] = {"wav": relative_path, "length": duration}

    # Writing the dictionary to the json file
    with open(json_file, mode="w") as json_f:
        json.dump(json_dict, json_f, indent=2)

    logger.info(f"{json_file} successfully created!")


def skip(*filenames):
    """
    Detects if the data preparation has been already done.
    If the preparation has been done, we can skip it.

    Returns
    -------
    bool
        if True, the preparation phase can be skipped.
        if False, it must be done.
    """
    for filename in filenames:
        if not os.path.isfile(filename):
            return False
    return True


def check_folders(*folders):
    """Returns False if any passed folder does not exist."""
    for folder in folders:
        if not os.path.exists(folder):
            return False
    return True


prepare_fa_speach(voices_folder_path, 'train.json', 'valid.json', 'test.json')

# %% [markdown]
# # Define BrainSpeech Module

# %%
# Brain class for speech enhancement training
class SEBrain(sb.Brain):
    def compute_forward(self, batch, stage):
        """Apply masking to convert from noisy waveforms to enhanced signals.

        Arguments
        ---------
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.

        Returns
        -------
        predictions : dict
            A dictionary with keys {"spec", "wav"} with predicted features.
        """

        # We first move the batch to the appropriate device, and
        # compute the features necessary for masking.
        batch = batch.to(self.device)
        noisy_wavs, lens = batch.noisy_sig
        noisy_feats = self.compute_feats(noisy_wavs)

        # Masking is done here with the "signal approximation (SA)" algorithm.
        # The masked input is compared directly with clean speech targets.
        mask = self.modules.model(noisy_feats)
        predict_spec = torch.mul(mask, noisy_feats)

        # Also return predicted wav, for evaluation. Note that this could
        # also be used for a time-domain loss term.
        predict_wav = self.hparams.resynth(
            torch.expm1(predict_spec), noisy_wavs
        )

        # Return a dictionary so we don't have to remember the order
        return {"spec": predict_spec, "wav": predict_wav}

    def compute_feats(self, wavs):
        """Returns corresponding log-spectral features of the input waveforms.

        Arguments
        ---------
        wavs : torch.Tensor
            The batch of waveforms to convert to log-spectral features.
        """

        # Log-spectral features
        feats = self.hparams.compute_STFT(wavs)
        feats = sb.processing.features.spectral_magnitude(feats, power=0.5)

        # Log1p reduces the emphasis on small differences
        feats = torch.log1p(feats)

        return feats

    def compute_objectives(self, predictions, batch, stage):
        """Computes the loss given the predicted and targeted outputs.

        Arguments
        ---------
        predictions : dict
            The output dict from `compute_forward`.
        batch : PaddedBatch
            This batch object contains all the relevant tensors for computation.
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.

        Returns
        -------
        loss : torch.Tensor
            A one-element tensor used for backpropagating the gradient.
        """

        # Prepare clean targets for comparison
        clean_wavs, lens = batch.clean_sig
        clean_spec = self.compute_feats(clean_wavs)

        # Directly compare the masked spectrograms with the clean targets
        loss = sb.nnet.losses.mse_loss(predictions["spec"], clean_spec, lens)

        # Append this batch of losses to the loss metric for easy
        self.loss_metric.append(
            batch.id, predictions["spec"], clean_spec, lens, reduction="batch"
        )

        # Some evaluations are slower, and we only want to perform them
        # on the validation set.
        if stage != sb.Stage.TRAIN:

            # Evaluate speech intelligibility as an additional metric
            self.stoi_metric.append(
                batch.id,
                predictions["wav"],
                clean_wavs,
                lens,
                reduction="batch",
            )

        return loss

    def on_stage_start(self, stage, epoch=None):
        """Gets called at the beginning of each epoch.

        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, or sb.Stage.TEST.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Set up statistics trackers for this stage
        self.loss_metric = sb.utils.metric_stats.MetricStats(
            metric=sb.nnet.losses.mse_loss
        )

        # Set up evaluation-only statistics trackers
        if stage != sb.Stage.TRAIN:
            self.stoi_metric = sb.utils.metric_stats.MetricStats(
                metric=sb.nnet.loss.stoi_loss.stoi_loss
            )

    def on_stage_end(self, stage, stage_loss, epoch=None):
        """Gets called at the end of an epoch.

        Arguments
        ---------
        stage : sb.Stage
            One of sb.Stage.TRAIN, sb.Stage.VALID, sb.Stage.TEST
        stage_loss : float
            The average loss for all of the data processed in this stage.
        epoch : int
            The currently-starting epoch. This is passed
            `None` during the test stage.
        """

        # Store the train loss until the validation stage.
        if stage == sb.Stage.TRAIN:
            self.train_loss = stage_loss

        # Summarize the statistics from the stage for record-keeping.
        else:
            stats = {
                "loss": stage_loss,
                "stoi": -self.stoi_metric.summarize("average"),
            }

        # At the end of validation, we can write stats and checkpoints
        if stage == sb.Stage.VALID:
            # The train_logger writes a summary to stdout and to the logfile.
            self.hparams.train_logger.log_stats(
                {"Epoch": epoch},
                train_stats={"loss": self.train_loss},
                valid_stats=stats,
            )

            # Save the current checkpoint and delete previous checkpoints,
            # unless they have the current best STOI score.
            self.checkpointer.save_and_keep_only(meta=stats, max_keys=["stoi"])

        # We also write statistics about test data to stdout and to the logfile.
        if stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                {"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stats,
            )

# %% [markdown]
# ## Define audio pipeline.
#  Adds noise, reverb, and babble on-the-fly.

# %%
def dataio_prep(hparams):
  # Define audio pipeline. Adds noise, reverb, and babble on-the-fly.
  # Of course for a real enhancement dataset, you'd want a fixed test set.
  @sb.utils.data_pipeline.takes("wav")
  @sb.utils.data_pipeline.provides("noisy_sig", "clean_sig")
  def audio_pipeline(wav):
    """Load the signal, and pass it and its length to the corruption class.
    This is done on the CPU in the `collate_fn`."""
    clean_sig = sb.dataio.dataio.read_audio(wav)
    noisy_sig = hparams["env_corruption"](
      clean_sig.unsqueeze(0), torch.ones(1)
    ).squeeze(0)
    return noisy_sig, clean_sig

  # Define datasets sorted by ascending lengths for efficiency
  datasets = {}
  hparams["dataloader_options"]["shuffle"] = False
  for dataset in ["train", "valid", "test"]:
    datasets[dataset] = sb.dataio.dataset.DynamicItemDataset.from_json(
      json_path=hparams[f"{dataset}_annotation"],
      replacements={"data_root": hparams["data_folder"]},
      dynamic_items=[audio_pipeline],
      output_keys=["id", "noisy_sig", "clean_sig"],
    ).filtered_sorted(sort_key="length")
  return datasets

# %% [markdown]
# # Train Model

# %% [markdown]
# ## Load data, Create BrainSpeech instance and train it

# %%
from hyperpyyaml import load_hyperpyyaml
with open("train.yaml") as fin:
  hparams = load_hyperpyyaml(fin)
# Out:
# ./data/rirs_noises.zip exists. Skipping download

# %%
# Create experiment directory

sb.create_experiment_directory(
    experiment_directory=hparams["output_folder"],
    hyperparams_to_save="train.yaml"
)
# Out:
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/5020

# %%
#load data
datasets = dataio_prep(hparams)

# %%
# Create BrainSpeech instance
se_brain = SEBrain(
  modules=hparams["modules"],
  opt_class=hparams["opt_class"],
  hparams=hparams,
  run_opts={'device': device},
  checkpointer=hparams["checkpointer"],
)
# Out:
# speechbrain.core - 2.0M trainable parameters in SEBrain

# %%
se_brain.fit(
  epoch_counter=se_brain.hparams.epoch_counter,
  train_set=datasets["train"],
  valid_set=datasets["valid"],
  train_loader_kwargs=hparams["dataloader_options"],
  valid_loader_kwargs=hparams["dataloader_options"],
)

# %%
se_brain.evaluate(
  test_set=datasets["test"],
  max_key="stoi",
  test_loader_kwargs=hparams["dataloader_options"],
)

# %% [markdown]
# # See results

# %%
for data_subset in see_results:

  # directory to save results
  sample_dir = hparams['output_folder'] + '/samples/' + data_subset

  # create directory if it doesnt exist
  if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

  # Choose random samples from subset
  shuffeled_idxs = np.random.permutation(len(datasets[data_subset]))
  for idx in shuffeled_idxs[:sample_num]:

    ## get sample from dataloader
    sample_input = datasets[data_subset][idx]['noisy_sig']
    sample_output = datasets[data_subset][idx]['clean_sig']

    ## set name for generated audios
    sample_input_name = sample_dir+'/sample_{}_in.wav'.format(idx)
    sample_output_name = sample_dir+'/sample_{}_out.wav'.format(idx)
    sample_pred_name = sample_dir+'/sample_{}_pred.wav'.format(idx)



    ## get prediction
    ### get sample spectrum
    noisy_wavs = sample_input.unsqueeze(0)
    noisy_feats = se_brain.compute_feats(noisy_wavs)
    ### predict sample mask
    mask = se_brain.modules.model(noisy_feats)
    ### apply predicted mask
    predict_spec = torch.mul(mask, noisy_feats)
    ### get predicted audio from spectrum
    predict_wav = se_brain.hparams.resynth(torch.expm1(predict_spec), noisy_wavs)

    ## save audios to file
    sb.dataio.dataio.write_audio(sample_input_name, sample_input, hparams["sample_rate"])
    sb.dataio.dataio.write_audio(sample_output_name, sample_output, hparams["sample_rate"])
    sb.dataio.dataio.write_audio(sample_pred_name, predict_wav[0], hparams["sample_rate"])

    # ## show samples in jupyternotebook
    # ## warning: this part ma cause jupyternotebook to crash

    # print(sample_input_name)
    # display(Audio(sample_in_name, autoplay=True))

    # print(sample_output_name)
    # display(Audio(sample_out_name, autoplay=True))

    # print(sample_pred_name)
    # display(Audio(sample_pred_name, autoplay=True))
    # print("+++++++++++++++++++++++++++++++")

# %% [markdown]
# # Save Results
# Copy trained model, results and logs to `save_path`

# %%
import shutil

shutil.copytree(hparams['output_folder'], save_path)
# Out:
# '/content/drive/MyDrive/FA_spech_enhance_exp_5020/'
